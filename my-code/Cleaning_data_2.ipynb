# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
train_mod=pd.read_csv("../data/outcomes_models/train_mod1.csv")

# %%
train_mod.head(3)
# Out:
#    Unnamed: 0 host_location  host_response_time  host_response_rate  \
# 0           0   Netherlands  within a few hours                 100
# 1           1   Netherlands             unknown                   0
# 2           2   Netherlands      within an hour                 100
#
#    host_acceptance_rate host_is_superhost        host_neighbourhood  \
# 0                    75                 f                   unknown
# 1                     0                 f  Weesperbuurt en Plantage
# 2                    97                 t       Hoofddorppleinbuurt
#
#    host_listings_count  host_total_listings_count  \
# 0                   13                         13
# 1                    0                          0
# 2                   20                         20
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 1                      ['email', 'phone', 'reviews']                    t
# 2                                 ['email', 'phone']                    t
#
#   host_identity_verified neighbourhood_cleansed  latitude  longitude  \
# 0                      t             Noord-Oost  52.39508    4.99186
# 1                      f           Centrum-Oost  52.36371    4.90745
# 2                      t                   Zuid  52.35482    4.85329
#
#                 property_type        room_type  accommodates  \
# 0   Private room in farm stay     Private room             3
# 1          Entire rental unit  Entire home/apt             4
# 2  Room in serviced apartment       Hotel room             2
#
#      bathrooms_text  bedrooms      beds  \
# 0  1.5 shared baths       1.0  1.956424
# 1            1 bath       2.0  2.000000
# 2    1 private bath       1.0  1.000000
#
#                                            amenities  price  minimum_nights  \
# 0  ["First aid kit", "Free parking on premises", ...   87.0               2
# 1  ["Hot water kettle", "Pocket wifi", "Stove", "...  250.0               2
# 2  ["Air conditioning", "First aid kit", "Hangers...  151.0               1
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0            1125                     2.0                     2.0
# 1            1125                     2.0                     2.0
# 2            1125                     1.0                     1.0
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                  1125.0                  1125.0                     2.0
# 1                  1125.0                  1125.0                     2.0
# 2                    99.0                    99.0                     1.0
#
#    maximum_nights_avg_ntm has_availability  availability_30  availability_60  \
# 0                  1125.0                t                0                0
# 1                  1125.0                t                3                3
# 2                    99.0                t               25               55
#
#    availability_90  availability_365  number_of_reviews  \
# 0                0               249                 81
# 1                3                 3                  9
# 2               85               267                 47
#
#    number_of_reviews_ltm  number_of_reviews_l30d last_review  \
# 0                      0                       0  2019-06-15
# 1                      4                       1  2021-09-05
# 2                      3                       1  2020-03-07
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                  4.62                    4.56                       4.29
# 1                  5.00                    5.00                       5.00
# 2                  4.79                    4.83                       4.91
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   4.57                         4.75                    4.69
# 1                   4.89                         5.00                    5.00
# 2                   4.62                         4.87                    4.87
#
#    review_scores_value instant_bookable  calculated_host_listings_count  \
# 0                 4.49                f                              10
# 1                 4.89                f                               1
# 2                 4.40                t                              20
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            1
# 2                                            4
#
#    calculated_host_listings_count_private_rooms  \
# 0                                            10
# 1                                             0
# 2                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.91
# 1                                            0               0.40
# 2                                            0               1.25

# %%
# Dejamos solo el país del host_location
    
for j in range(len(train_mod.host_location)):

    train_mod.host_location[j]=train_mod.host_location[j].rsplit(None, 1)[-1]
# Out:
# /var/folders/tr/7ry1klqj22sglvfj6nq3g5kw0000gn/T/ipykernel_61375/2910111825.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_mod.host_location[j]=train_mod.host_location[j].rsplit(None, 1)[-1]

# %%
train_mod.host_location.unique()
# Out:
# array(['Netherlands', 'NL', 'States', 'US', 'GB', 'unknown', 'RS',
#        'Spain', 'Ireland', 'Kingdom', 'Switzerland', 'Canada', 'Romania',
#        'Australia', 'ES', 'Germany', 'DE', 'Africa', 'BR', 'Emirates',
#        'Belgium', 'London', 'Lithuania', 'China', 'Singapore', 'Denmark',
#        'NO', 'Nederland', 'GR', 'Sweden', 'Turkey', 'Finland', 'Italy',
#        'nb130', 'FR', 'France', 'IT', 'Argentina', 'PL', 'HR', 'Colombia'],
#       dtype=object)

# %%
train_mod.host_location.replace("Nederland","Netherlands")
# Out:
# 0       Netherlands
# 1       Netherlands
# 2       Netherlands
# 3       Netherlands
# 4       Netherlands
#            ...
# 4161    Netherlands
# 4162    Netherlands
# 4163    Netherlands
# 4164    Netherlands
# 4165         States
# Name: host_location, Length: 4166, dtype: object

# %%
train_mod.host_location.unique()
# Out:
# array(['Netherlands', 'NL', 'States', 'US', 'GB', 'unknown', 'RS',
#        'Spain', 'Ireland', 'Kingdom', 'Switzerland', 'Canada', 'Romania',
#        'Australia', 'ES', 'Germany', 'DE', 'Africa', 'BR', 'Emirates',
#        'Belgium', 'London', 'Lithuania', 'China', 'Singapore', 'Denmark',
#        'NO', 'GR', 'Sweden', 'Turkey', 'Finland', 'Italy', 'nb130',
#        'France', 'IT', 'Argentina', 'PL', 'HR', 'Colombia'], dtype=object)

# %%
train_mod.replace(to_replace ="Nederland",value ="Netherlands", inplace=True)
train_mod.replace(to_replace ="FR",value ="France", inplace=True)
